# %% [markdown]
# # Module 2 Color Exercise
#
# **For the exercises, we will create plots with correct and adequate color schemes similar to the lab and practice.**

# %%
library(ggplot2)
library(RColorBrewer)

# %% [markdown]
# **Activity 1:** Display colormaps with 7 colors from RColorBrewer library for a **sequential** data type with **colorblind safe** colors.

# %%
## Your answer for activity 1 goes here ---

display.brewer.pal(n=7, name='BuGn')
display.brewer.pal(n=7, name='BuPu')
display.brewer.pal(n=7, name='GnBu')
display.brewer.pal(n=7, name='OrRd')
display.brewer.pal(n=7, name='PuBu')
display.brewer.pal(n=7, name='PuBuGn')
# Out:
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title

# %% [markdown]
# **Activity 2:** Create a **colorblind safe colormap with 100 colors** from the dichromat library, and display their hexadecimal codes.

# %%
library(dichromat)
## Your answer for activity 2 goes here ---

pal <- function(col, ...)
image(seq_along(col), 1, matrix(seq_along(col), ncol = 1),
col = col, axes = FALSE, ...)


opar <- par(mar = c(1, 2, 1, 1))
layout(matrix(1:6, ncol = 1))
pal(colorschemes$BrowntoBlue.10, main = "Brown to Blue (10)")
colorschemes["BrowntoBlue.10"]
pal(colorschemes$BrowntoBlue.12, main = "Brown to Blue (12)")
colorschemes["BrowntoBlue.12"]
pal(colorschemes$BluetoDarkOrange.12, main = "Brown to Dark Orange (12)")
colorschemes["BluetoDarkOrange.12"]
pal(colorschemes$BluetoDarkOrange.18, main = "Brown to Dark Orange (18)")
colorschemes["BluetoDarkOrange.18"]
pal(colorschemes$DarkRedtoBlue.12, main = "Dark Red to Blue (12)")
colorschemes["DarkRedtoBlue.12"]
pal(colorschemes$DarkRedtoBlue.18, main = "Dark Red to Blue (18)")
colorschemes["DarkRedtoBlue.18"]
pal(colorschemes$BluetoOrange.10, main = "Blue to Orange (10)")
colorschemes["BluetoOrange.10"]
pal(colorschemes$BluetoOrange.8, main = "Blue to Orange (8)")
colorschemes["BluetoOrange.8"]

# This was the closest I could get to my understanding of the instructions.
# Out:
# $BrowntoBlue.10
#  [1] "#663000" "#996136" "#CC9B7A" "#D9AF98" "#F2DACE" "#CCFDFF" "#99F8FF"
#  [8] "#66F0FF" "#33E4FF" "#00AACC"
# $BrowntoBlue.12
#  [1] "#331A00" "#663000" "#996136" "#CC9B7A" "#D9AF98" "#F2DACE" "#CCFDFF"
#  [8] "#99F8FF" "#66F0FF" "#33E4FF" "#00AACC" "#007A99"
# $BluetoDarkOrange.12
#  [1] "#1F8F99" "#52C4CC" "#99FAFF" "#B2FCFF" "#CCFEFF" "#E6FFFF" "#FFE6CC"
#  [8] "#FFCA99" "#FFAD66" "#FF8F33" "#CC5800" "#994000"
# $BluetoDarkOrange.18
#  [1] "#006666" "#009999" "#00CCCC" "#00FFFF" "#33FFFF" "#66FFFF" "#99FFFF"
#  [8] "#B2FFFF" "#CCFFFF" "#E6FFFF" "#FFE6CC" "#FFCA99" "#FFAD66" "#FF8F33"
# [15] "#FF6E00" "#CC5500" "#993D00" "#662700"
# $DarkRedtoBlue.12
#  [1] "#2A0BD9" "#264EFF" "#40A1FF" "#73DAFF" "#ABF8FF" "#E0FFFF" "#FFFFBF"
#  [8] "#FFE099" "#FFAD73" "#F76E5E" "#D92632" "#A60021"
# $DarkRedtoBlue.18
#  [1] "#2400D9" "#191DF7" "#2957FF" "#3D87FF" "#57B0FF" "#75D3FF" "#99EBFF"
#  [8] "#BDF9FF" "#EBFFFF" "#FFFFEB" "#FFF2BD" "#FFD699" "#FFAC75" "#FF7857"
# ...

# %% [markdown]
# **Activity 3:** Use ellipse library to create an elliptical correlation plot for the diamonds data using carat, price, table, and depth variables. Make sure to use a **colorblind safe, diverging** color scheme.

# %%
library(ellipse)
head(diamonds)
data=diamonds[,c("carat","depth","price","table")]
## Your answer for activity 3 goes here ---

data=cor(data)

my_colors <- brewer.pal(5, "RdBu")
my_colors=colorRampPalette(my_colors)(100)

ord <- order(data[1, ])
data_ord = data[ord, ord]

plotcorr(data_ord , col=my_colors[data_ord*50+50], mar=c(1,1,1,1))
# Out:
#   carat cut       color clarity depth table price x    y    z
# 1 0.23  Ideal     E     SI2     61.5  55    326   3.95 3.98 2.43
# 2 0.21  Premium   E     SI1     59.8  61    326   3.89 3.84 2.31
# 3 0.23  Good      E     VS1     56.9  65    327   4.05 4.07 2.31
# 4 0.29  Premium   I     VS2     62.4  58    334   4.20 4.23 2.63
# 5 0.31  Good      J     SI2     63.3  58    335   4.34 4.35 2.75
# 6 0.24  Very Good J     VVS2    62.8  57    336   3.94 3.96 2.48
# plot without title

# %% [markdown]
# **Activity 4:** Create a scatter plot using **all** diamonds data for carat vs. price and encode clarity variable with a **sequential** color scheme.

# %%
## Your answer for activity 4 goes here ---


gp <- ggplot(diamonds, aes(x=carat, y=price, color=clarity)) + geom_point() + scale_color_brewer(palette="BuGn")
gp
# Out:
# plot without title

# %% [markdown]
# **Activity 5:** Repeat Activity 4 with **alpha transparency**. **Is this a better idea? Discuss your answer.**

# %%
## Your answer for activity 5 goes here ---


# hint: geom_point(alpha=0.5)

gp2 <- ggplot(diamonds, aes(x=carat, y=price, color=clarity)) + geom_point(alpha=0.5) + scale_color_brewer(palette="BuGn")
gp2

# I think this is a better idea, because you can see better where there is a higher concentration of points, and make out
# individual points better
# Out:
# plot without title

# %% [markdown]
# **Activity 6:** Recreate the following plot using `ggplot2` functions and the **mtcars** data set. Hint: you may have to change attribute characteristics, also look at theme functions in `ggplot2`.
#
# <img src="ex.png">

# %%
## Your answer for activity 6 goes here ---
library(dplyr)

dcars <- mtcars %>% mutate_at(c("cyl"), as.character)

gp3 <- ggplot(dcars, aes(x=wt, y=mpg, color=cyl, size=qsec)) + geom_point(alpha=0.5) + geom_smooth(method='lm')
gp3 + theme_bw() + theme_minimal()
# Out:
# plot without title
