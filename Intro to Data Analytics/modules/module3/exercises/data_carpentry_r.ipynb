# %% [markdown]
# # Data Carpentry for a Mini Analysis (`R`)

# %% [markdown]
# **Exercise 1:** Read in the dataset, `/dsa/data/all_datasets/baseball-databank/data/Master.csv`. Call this data frame, `df`.

# %%
library(dplyr)
library(tidyr)
library(lubridate)

# %%
# Code for Exercise 1 goes here
# -----------------------------

df <- read.csv('/dsa/data/all_datasets/baseball-databank/data/Master.csv')
df
# Out:
#       playerID  birthYear birthMonth birthDay birthCountry birthState
# 1     aardsda01 1981      12         27       USA          CO
# 2     aaronha01 1934       2          5       USA          AL
# 3     aaronto01 1939       8          5       USA          AL
# 4     aasedo01  1954       9          8       USA          CA
# 5     abadan01  1972       8         25       USA          FL
# 6     abadfe01  1985      12         17       D.R.         La Romana
# 7     abadijo01 1854      11          4       USA          PA
# 8     abbated01 1877       4         15       USA          PA
# 9     abbeybe01 1869      11         11       USA          VT
# 10    abbeych01 1866      10         14       USA          NE
# 11    abbotda01 1862       3         16       USA          OH
# 12    abbotfr01 1874      10         22       USA          OH
# 13    abbotgl01 1951       2         16       USA          AR
# 14    abbotje01 1972       8         17       USA          GA
# 15    abbotji01 1967       9         19       USA          MI
# 16    abbotku01 1969       6          2       USA          OH
# 17    abbotky01 1968       2         18       USA          MA
# 18    abbotod01 1888       9          5       USA          PA
# 19    abbotpa01 1967       9         15       USA          CA
# 20    aberal01  1927       7         31       USA          OH
# 21    abercda01 1850       1          2       USA          OK
# 22    abercre01 1980       7         15       USA          GA
# 23    abernbi01 1929       1         30       USA          CA
# 24    abernbr01 1977       9         23       USA          GA
# 25    abernte01 1921      10         30       USA          NC
# 26    abernte02 1933       3          6       USA          NC
# 27    abernwo01 1915       2          1       USA          NC
# 28    aberscl01 1921       8         28       USA          IL
# 29    ablesha01 1883      10          4       USA          TX
# 30    abnersh01 1966       6         17       USA          OH
# ⋮     ⋮         ⋮         ⋮          ⋮        ⋮            ⋮
# 18817 zimmejo02 1986       5         23       USA          WI
# 18818 zimmero01 1916       9         13       USA          PA
# 18819 zimmery01 1984       9         28       USA          NC
# 18820 zinkch01  1979       8         26       USA          CA
# 18821 zinkwa01  1898      11         21       USA          MA
# 18822 zinnfr01  1865      12         21       USA          PA
# 18823 zinngu01  1887       2         13       USA          WV
# 18824 zinnji01  1895       1         21       USA          AR
# 18825 zinsebi01 1918       1          6       USA          NY
# 18826 zinteal01 1968       5         19       USA          TX
# 18827 zipfebu01 1938      11         18       USA          IL
# 18828 ziskri01  1949       2          6       USA          NY
# 18829 zitoba01  1978       5         13       USA          NV
# 18830 zitzmbi01 1895      11         19       USA          NY
# 18831 zmiched01 1884      10          1       USA          OH
# 18832 zobribe01 1981       5         26       USA          IL
# 18833 zoccope01 1977       2          6       USA          NY
# 18834 zoldasa01 1918      12          8       USA          NY
# 18835 zoskyed01 1968       2         10       USA          CA
# 18836 zuberbi01 1913       3         26       USA          IA
# 18837 zuberjo01 1969      12         10       USA          CA
# 18838 zuletju01 1975       3         28       Panama       Panama
# 18839 zumayjo01 1984      11          9       USA          CA
# 18840 zuninmi01 1991       3         25       USA          FL
# 18841 zupcibo01 1966       8         18       USA          PA
# 18842 zupofr01  1939       8         29       USA          CA
# 18843 zuvelpa01 1958      10         31       USA          CA
# 18844 zuverge01 1924       8         20       USA          MI
# 18845 zwilldu01 1888      11          2       USA          MO
# 18846 zychto01  1990       8          7       USA          IL
#       birthCity        deathYear deathMonth deathDay ⋯ nameLast
# 1     Denver             NA      NA         NA       ⋯ Aardsma
# 2     Mobile             NA      NA         NA       ⋯ Aaron
# 3     Mobile           1984       8         16       ⋯ Aaron
# 4     Orange             NA      NA         NA       ⋯ Aase
# 5     Palm Beach         NA      NA         NA       ⋯ Abad
# 6     La Romana          NA      NA         NA       ⋯ Abad
# 7     Philadelphia     1905       5         17       ⋯ Abadie
# 8     Latrobe          1957       1          6       ⋯ Abbaticchio
# 9     Essex            1962       6         11       ⋯ Abbey
# 10    Falls City       1926       4         27       ⋯ Abbey
# 11    Portage          1930       2         13       ⋯ Abbott
# 12    Versailles       1935       6         11       ⋯ Abbott
# 13    Little Rock        NA      NA         NA       ⋯ Abbott
# 14    Atlanta            NA      NA         NA       ⋯ Abbott
# 15    Flint              NA      NA         NA       ⋯ Abbott
# 16    Zanesville         NA      NA         NA       ⋯ Abbott
# 17    Newburyport        NA      NA         NA       ⋯ Abbott
# 18    New Eagle        1933       4         13       ⋯ Abbott
# 19    Van Nuys           NA      NA         NA       ⋯ Abbott
# 20    Cleveland        1993       5         20       ⋯ Aber
# 21    Fort Towson      1939      11         11       ⋯ Abercrombie
# 22    Columbus           NA      NA         NA       ⋯ Abercrombie
# 23    Torrance         2006       2         19       ⋯ Abernathie
# 24    Atlanta            NA      NA         NA       ⋯ Abernathy
# 25    Bynum            2001      11         16       ⋯ Abernathy
# 26    Stanley          2004      12         16       ⋯ Abernathy
# 27    Forest City      1994      12          5       ⋯ Abernathy
# 28    Chicago          1973       6         23       ⋯ Aberson
# 29    Terrell          1951       2          8       ⋯ Ables
# 30    Hamilton           NA      NA         NA       ⋯ Abner
# ⋮     ⋮                ⋮         ⋮          ⋮        ⋱ ⋮
# 18817 Auburndale         NA      NA         NA       ⋯ Zimmermann
# 18818 Pine Grove       1991      11         22       ⋯ Zimmerman
# 18819 Washington         NA      NA         NA       ⋯ Zimmerman
# 18820 Carmichael         NA      NA         NA       ⋯ Zink
# 18821 Pittsfield       1964       6         12       ⋯ Zink
# 18822 Phoenixville     1936       5         12       ⋯ Zinn
# 18823 Holbrook         1949      10          6       ⋯ Zinn
# 18824 Benton           1991       2         26       ⋯ Zinn
# 18825 Astoria          1993       2         16       ⋯ Zinser
# 18826 El Paso            NA      NA         NA       ⋯ Zinter
# 18827 Belleville         NA      NA         NA       ⋯ Zipfel
# 18828 Brooklyn           NA      NA         NA       ⋯ Zisk
# 18829 Las Vegas          NA      NA         NA       ⋯ Zito
# 18830 Long Island City 1985       5         29       ⋯ Zitzmann
# 18831 Cleveland        1950       8         20       ⋯ Zmich
# 18832 Eureka             NA      NA         NA       ⋯ Zobrist
# 18833 Bronx              NA      NA         NA       ⋯ Zoccolillo
# 18834 Brooklyn         1966       8         25       ⋯ Zoldak
# 18835 Whittier           NA      NA         NA       ⋯ Zosky
# 18836 Middle Amana     1982      11          2       ⋯ Zuber
# 18837 Encino             NA      NA         NA       ⋯ Zuber
# 18838 Panama             NA      NA         NA       ⋯ Zuleta
# 18839 Chula Vista        NA      NA         NA       ⋯ Zumaya
# 18840 Cape Coral         NA      NA         NA       ⋯ Zunino
# 18841 Pittsburgh         NA      NA         NA       ⋯ Zupcic
# 18842 San Francisco    2005       3         25       ⋯ Zupo
# 18843 San Mateo          NA      NA         NA       ⋯ Zuvella
# 18844 Holland          2014       9          8       ⋯ Zuverink
# 18845 St. Louis        1978       3         27       ⋯ Zwilling
# 18846 Monee              NA      NA         NA       ⋯ Zych
#       nameGiven          weight height bats throws debut      finalGame
# 1     David Allan        220    75     R    R      2004-04-06 2015-08-23
# 2     Henry Louis        180    72     R    R      1954-04-13 1976-10-03
# 3     Tommie Lee         190    75     R    R      1962-04-10 1971-09-26
# 4     Donald William     190    75     R    R      1977-07-26 1990-10-03
# 5     Fausto Andres      184    73     L    L      2001-09-10 2006-04-13
# 6     Fernando Antonio   220    73     L    L      2010-07-28 2015-10-03
# 7     John W.            192    72     R    R      1875-04-26 1875-06-10
# 8     Edward James       170    71     R    R      1897-09-04 1910-09-15
# 9     Bert Wood          175    71     R    R      1892-06-14 1896-09-23
# 10    Charles S.         169    68     L    L      1893-08-16 1897-08-19
# 11    Leander Franklin   190    71     R    R      1890-04-19 1890-05-23
# 12    Harry Frederick    180    70     R    R      1903-04-25 1905-09-20
# 13    William Glenn      200    78     R    R      1973-07-29 1984-08-08
# 14    Jeffrey William    190    74     R    L      1997-06-10 2001-09-29
# 15    James Anthony      200    75     L    L      1989-04-08 1999-07-21
# 16    Kurt Thomas        180    71     R    R      1993-09-07 2001-04-13
# 17    Lawrence Kyle      200    76     L    L      1991-09-10 1996-08-24
# 18    Ody Cleon          180    74     R    R      1910-09-10 1910-10-15
# 19    Paul David         185    75     R    R      1990-08-21 2004-08-07
# 20    Albert Julius      195    74     L    L      1950-09-15 1957-09-11
# 21    Francis Patterson   NA    NA                 1871-10-21 1871-10-21
# 22    Reginald Damascus  215    75     R    R      2006-04-04 2008-09-28
# 23    William Edward     190    70     R    R      1952-09-27 1952-09-27
# 24    Michael Brent      185    73     R    R      2001-06-25 2005-09-29
# 25    Talmadge Lafayette 210    74     R    L      1942-09-19 1944-04-29
# 26    Theodore Wade      215    76     R    R      1955-04-13 1972-09-30
# 27    Virgil Woodrow     170    72     L    L      1946-07-28 1947-04-17
# 28    Clifford Alexander 200    72     R    R      1947-07-18 1949-05-09
# 29    Harry Terrell      200    74     R    L      1905-09-04 1911-05-05
# 30    Shawn Wesley       190    73     R    R      1987-09-08 1992-10-03
# ⋮     ⋮                  ⋮      ⋮      ⋮    ⋮      ⋮          ⋮
# 18817 Jordan M.          225    74     R    R      2009-04-20 2015-09-30
# 18818 Roy Franklin       187    74     L    L      1945-08-27 1945-09-30
# 18819 Ryan Wallace       220    75     R    R      2005-09-01 2015-09-07
# 18820 Charles Tadao      190    73     R    R      2008-08-12 2008-08-12
# 18821 Walter Noble       165    72     R    R      1921-07-06 1921-07-19
# 18822 Frank Patrick      150    68                 1888-04-18 1888-05-03
# 18823 Guy                170    70     L    R      1911-09-11 1915-09-16
# 18824 James Edward       195    72     L    R      1919-09-04 1929-08-25
# 18825 William Francis    185    73     R    R      1944-08-19 1944-08-26
# 18826 Alan Michael       200    74     B    R      2002-06-18 2004-10-03
# 18827 Marion Sylvester   200    75     L    R      1961-07-26 1962-09-30
# 18828 Richard Walter     200    73     R    R      1971-09-08 1983-09-21
# 18829 Barry William      205    74     L    L      2000-07-22 2015-09-30
# 18830 William Arthur     175    70     R    R      1919-04-27 1929-09-25
# 18831 Edward Albert      180    72     L    L      1910-07-23 1911-06-01
# 18832 Benjamin Thomas    210    75     B    R      2006-08-01 2015-10-04
# 18833 Peter Jude         200    74     L    R      2003-09-05 2003-09-28
# 18834 Samuel Walter      185    71     L    L      1944-05-13 1952-08-26
# 18835 Edward James       175    72     R    R      1991-09-02 2000-10-01
# 18836 William Henry      195    74     R    R      1936-09-16 1947-09-23
# 18837 Jon Edward         190    73     L    L      1996-04-19 1998-09-27
# 18838 Julio Ernesto      230    78     R    R      2000-04-06 2001-06-25
# 18839 Joel Martin        215    75     R    R      2006-04-03 2010-06-28
# 18840 Michael Accorsi    220    74     R    R      2013-06-12 2015-08-27
# 18841 Robert             220    76     R    R      1991-09-07 1994-08-04
# 18842 Frank Joseph       182    71     L    R      1957-07-01 1961-05-09
# 18843 Paul               173    72     R    R      1982-09-04 1991-05-02
# 18844 George             195    76     R    R      1951-04-21 1959-06-15
# 18845 Edward Harrison    160    66     L    L      1910-08-14 1916-07-12
# 18846 Anthony Aaron      190    75     R    R      2015-09-04 2015-10-03
#       retroID  bbrefID
# 1     aardd001 aardsda01
# 2     aaroh101 aaronha01
# 3     aarot101 aaronto01
# 4     aased001 aasedo01
# 5     abada001 abadan01
# 6     abadf001 abadfe01
# 7     abadj101 abadijo01
# 8     abbae101 abbated01
# 9     abbeb101 abbeybe01
# 10    abbec101 abbeych01
# 11    abbod101 abbotda01
# 12    abbof101 abbotfr01
# 13    abbog001 abbotgl01
# 14    abboj002 abbotje01
# 15    abboj001 abbotji01
# 16    abbok002 abbotku01
# 17    abbok001 abbotky01
# 18    abboo101 abbotod01
# 19    abbop001 abbotpa01
# 20    abera101 aberal01
# 21    aberd101 abercda01
# 22    aberr001 abercre01
# 23    aberb101 abernbi01
# 24    aberb001 abernbr01
# 25    abert102 abernte01
# 26    abert101 abernte02
# 27    aberw101 abernwo01
# 28    aberc101 aberscl01
# 29    ableh101 ablesha01
# 30    abnes001 abnersh01
# ⋮     ⋮        ⋮
# 18817 zimmj003 zimmejo02
# 18818 zimmr101 zimmero01
# 18819 zimmr001 zimmery01
# 18820 zinkc001 zinkch01
# 18821 zinkw101 zinkwa01
# 18822 zinnf101 zinnfr01
# 18823 zinng101 zinngu01
# 18824 zinnj101 zinnji01
# 18825 zinsb101 zinsebi01
# 18826 zinta001 zinteal01
# 18827 zipfb101 zipfebu01
# 18828 ziskr101 ziskri01
# 18829 zitob001 zitoba01
# 18830 zitzb101 zitzmbi01
# 18831 zmice101 zmiched01
# 18832 zobrb001 zobribe01
# 18833 zoccp001 zoccope01
# 18834 zolds101 zoldasa01
# 18835 zoske001 zoskyed01
# 18836 zubeb101 zuberbi01
# 18837 zubej001 zuberjo01
# 18838 zulej001 zuletju01
# 18839 zumaj001 zumayjo01
# 18840 zunim001 zuninmi01
# 18841 zupcb001 zupcibo01
# 18842 zupof101 zupofr01
# 18843 zuvep001 zuvelpa01
# 18844 zuveg101 zuverge01
# 18845 zwild101 zwilldu01
# 18846 zycht001 zychto01

# %% [markdown]
# We are not interested in the columns dealing with death for these exercises. Let's go ahead and get rid of them.

# %% [markdown]
# **Exercise 2:** Remove the `deathYear`, `deathMonth`, `deathDay`, `deathCountry`, `deathState`, and `deathCity` columns from the data frame. Rename the data frame without these columns, `players`.

# %%
# Code for Exercise 2 goes here
# -----------------------------

players <- subset(df, select = -c(deathYear, deathMonth, deathDay, deathCountry, deathState, deathCity))

# %% [markdown]
# **Exercise 3:** Create a date column called `players$birthdate` by combining the `birthYear`, `birthMonth` and `birthDay` columns, then delete these columns.

# %%
# Code for Exercise 3 goes here
# -----------------------------

players$birthdate <- paste(df$birthYear, df$birthMonth, df$birthDay)
players <- subset(players, select = -c(birthYear, birthMonth, birthDay))

# %% [markdown]
# **Exercise 4**: Now convert the `players$debut` and `players$finalGame` columns to date columns.

# %%
# Code for Exercise 4 goes here
# -----------------------------

players$debut <- as.Date(players$debut)
players$finalGame <- as.Date(players$finalGame)

# %% [markdown]
# This is a good time to discuss how to calculate differences between times. `lubridate` provides some convenient ways to do this by simply subtracting one date from another. See the example below.

# %%
delta<-dmy("01-03-2017")-mdy("August 1st, 2000")
delta
# Out:
# Time difference of 6056 days

# %% [markdown]
# **Exercise 5**: Create a new column in the players data frame called `debut_age` that finds the difference in days between a players birth and their debut.

# %%
# Code for Exercise 5 goes here
# -----------------------------

players$debut_age <- ymd(players$finalGame) - ymd(players$debut)

# %% [markdown]
# **Exercise 6**: Find the mean age in years of the `debut_age` column. (Hint: you may have to use the `as.numeric()` function on the `debut_age` column to remove the language around each value. Also, when finding the mean, you may need to use the `na.rm` parameter. Finally, remember,the `debut_age` values are currently in days but we want years)

# %%
# Code for Exercise 6 goes here
# -----------------------------

players$debut_age <- as.numeric(players$debut_age)

mean(players$debut_age, na.rm=TRUE)/365
# Out:
# [1] 4.827581

# %% [markdown]
# # Save your notebook, then `File > Close and Halt`
