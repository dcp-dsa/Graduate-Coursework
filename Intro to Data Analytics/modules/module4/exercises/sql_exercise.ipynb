# %% [markdown]
# # `SQL` Exercises
#
# We are going to continue down the path of querying our twitter database.
# For this exercise, much of our activities will revolve around querying the `tweet` table (in the practice we spent most of our time in the `hashtag` table).
# This time around, all of the queries will be written by you.
#
# **Please keep in mind** that if your query is taking a very long time,
# it is probably because you are scanning the entire database.
# You will want to put a `LIMIT` on the lowest level of your query in order for results to render quickly.
# Take for example a query configured like so
#
# ```sql
# SELECT <cols>
# FROM (
#     SELECT <cols>
#     FROM <tables>
#     LIMIT <int>) AS lowest_level_table
# ```
#
# The query in the parentheses will be executed first and then the query outside of it will be executed on the results of the query inside of the parentheses.
#
# ---
#
# Before we begin, we will establish a connection...

# %%
import psycopg2
import pandas as pd

try:
    connect_str = "dbname='twitter' user='dsa_ro_user' host='pgsql.dsa.lan' password='readonly'"
    # use our connection values to establish a connection
    conn = psycopg2.connect(connect_str)
except:
    print("Something went wrong...probably the wrong permissions")

# %% [markdown]
# We will start off with a simple query...
#
# **Exercise 1**: Write a query that returns all of the attributes and **200** rows from the tweet table. Then execute the query by running `pd.read_sql_query()`.

# %%
# Code for Exercise 1 goes here
# --------------

statement = """
SELECT *
FROM twitter.tweet
LIMIT 200
"""

pd.read_sql_query(statement,conn)
# Out:
#            tweet_id_str  job_id          created_at  \
# 0    845388387934724097     272 2017-03-24 21:34:32
# 1    845388388123496449     271 2017-03-24 21:34:32
# 2    845388388249198592     261 2017-03-24 21:34:32
# 3    845388388266070018     238 2017-03-24 21:34:32
# 4    845388388345806848     273 2017-03-24 21:34:32
# ..                  ...     ...                 ...
# 195  845388402409254912     272 2017-03-24 21:34:36
# 196  845388402497236993     305 2017-03-24 21:34:36
# 197  845388402593861632     302 2017-03-24 21:34:36
# 198  845388402715353088     295 2017-03-24 21:34:36
# 199  845388402753257472     271 2017-03-24 21:34:36
#
#                                                   text           from_user  \
# 0    @namemeifucan @AnnCoulter  now if one want to ...            26652097
# 1    Home Buying Tips - Negotiating Repairs for You...            21029189
# 2    RT @rolufss: if u voted for Tr*mp u are not al...           250370014
# 3    RT @rmcfcantando: The Matador - The White Buff...  814140205066293248
# 4    RT @BrandonDaGawd: #BigGuyTwitter step aside c...          3192727068
# ..                                                 ...                 ...
# 195  RT @fhDavidChadwick: All of us have stumbled e...           163960110
# 196  Staying home for Spring Break?!  Yeah us too.....          2712995562
# 197                  Yup, 100x https://t.co/EgzRFAtYYL            41208728
# 198  I have to give up half of my spring break to a...  715664179651194880
# 199                                 @_DanceJunkie Come          3307163075
#
#        from_user_id_str  from_user_name    from_user_fullname  \
# 0              26652097    LeslieContes         Leslie Contes
# 1              21029189    vegashomepro       Debbie Drummond
# 2             250370014     bryanmink15            Bryan Mink
# 3    814140205066293248    rmcfcantando  real madrid cantando
# 4            3192727068   michellepaz30                  Mami
# ..                  ...             ...                   ...
# 195           163960110         BHycutt            1982CUgrad
# 196          2712995562  GreeksFranklin      Greek's Franklin
# 197            41208728          DX_XVI                   BCJ
# 198  715664179651194880    toadkart6556     Michael stapleton
# 199          3307163075    evenicolevip               Eve VIP
#
#     from_user_created_at  from_user_followers  ...  \
# 0    2009-03-26 01:19:59                  263  ...
# 1    2009-02-16 21:18:54                 8470  ...
# 2    2011-02-10 23:37:39                  254  ...
# 3    2016-12-28 16:05:25                 1727  ...
# 4    2015-05-12 04:03:16                  626  ...
# ..                   ...                  ...  ...
# 195  2010-07-07 18:02:48                   95  ...
# 196  2014-08-06 21:43:00                  142  ...
# 197  2009-05-19 20:57:05                  432  ...
# 198  2016-03-31 22:16:51                   69  ...
# 199  2015-06-03 15:47:40                  221  ...
#
#              from_user_timezone             to_user      to_user_id_str  \
# 0    Eastern Time (US & Canada)  803257620890927104  803257620890927104
# 1    Pacific Time (US & Canada)                None                None
# 2    Central Time (US & Canada)                None                None
# 3                          None                None                None
# 4                          None                None                None
# ..                          ...                 ...                 ...
# 195  Eastern Time (US & Canada)                None                None
# 196                        None                None                None
# 197  Eastern Time (US & Canada)                None                None
# 198                        None                None                None
# 199  Pacific Time (US & Canada)           168780102           168780102
#
#      to_user_name                                             source  \
# 0    namemeifucan  <a href="http://twitter.com" rel="nofollow">Tw...
# 1            None  <a href="https://www.socialoomph.com" rel="nof...
# 2            None  <a href="http://twitter.com/download/iphone" r...
# 3            None  <a href="https://mobile.twitter.com" rel="nofo...
# 4            None  <a href="http://twitter.com/download/iphone" r...
# ..            ...                                                ...
# 195          None  <a href="http://twitter.com/download/iphone" r...
# 196          None  <a href="http://instagram.com" rel="nofollow">...
# 197          None  <a href="http://twitter.com/download/iphone" r...
# 198          None  <a href="http://twitter.com/download/iphone" r...
# 199  _DanceJunkie  <a href="http://twitter.com/#!/download/ipad" ...
#
#                          location_geo location_geo_0 location_geo_1  \
# 0                                None            NaN            NaN
# 1                                None            NaN            NaN
# 2                                None            NaN            NaN
# 3                                None            NaN            NaN
# 4                                None            NaN            NaN
# ..                                ...            ...            ...
# 195                              None            NaN            NaN
# 196  \0\0\0\0\0\0\0SÐí%½C@¬Ê¾+UÀ       39.48087      -86.05482
# 197                              None            NaN            NaN
# 198                              None            NaN            NaN
# 199                              None            NaN            NaN
#
#     iso_language  analysis_state
# 0             en               0
# 1             en               0
# 2             en               0
# 3             en               0
# 4             en               0
# ..           ...             ...
# 195           en               0
# 196           en               0
# 197           en               0
# 198           en               0
# 199           en               0
#
# [200 rows x 23 columns]

# %% [markdown]
# The `job_id` for this table refers to which city the tweet was collected from. Since we all now have some tie to Columbia, MO, we can query for those tweets that are specifically tied to Columbia. Columbia's `job_id` is 261.
#
# **Exercise 2**: Write and execute a query that pulls all attributes and 200 rows where the job id is 261.

# %%
# Code for Exercise 2 goes here
# --------------

statement = """
SELECT *
FROM twitter.tweet
WHERE job_id = 261
LIMIT 200
"""

pd.read_sql_query(statement,conn)
# Out:
#            tweet_id_str  job_id          created_at  \
# 0    845388388249198592     261 2017-03-24 21:34:32
# 1    845388391915118593     261 2017-03-24 21:34:33
# 2    845388393236348928     261 2017-03-24 21:34:34
# 3    845388393676705792     261 2017-03-24 21:34:34
# 4    845388395752902657     261 2017-03-24 21:34:34
# ..                  ...     ...                 ...
# 195  845389671072915456     261 2017-03-24 21:39:38
# 196  845389676957589506     261 2017-03-24 21:39:40
# 197  845389679902031876     261 2017-03-24 21:39:40
# 198  845389682817077254     261 2017-03-24 21:39:41
# 199  845389690891128832     261 2017-03-24 21:39:43
#
#                                                   text   from_user  \
# 0    RT @rolufss: if u voted for Tr*mp u are not al...   250370014
# 1    RT @TheManeater: The nation's top basketball r...   498838018
# 2         The future is bright https://t.co/rPRTBy21sU   140078549
# 3    RT @Mizzou: .@MizzouHoops https://t.co/L83Umb8kp6  3359958869
# 4             RT @MizzouHoops: https://t.co/MIc1ap9aZz  1698103249
# ..                                                 ...         ...
# 195  My only talent is an inhuman ability to never ...  1921298382
# 196  RT @GabeDeArmond: In case you were wondering, ...   111336633
# 197  RT @Mizzou: .@MizzouHoops https://t.co/L83Umb8kp6    37007656
# 198  RT @GabeDeArmond: In case you were wondering, ...   205060572
# 199           RT @MizzouHoops: https://t.co/MIc1ap9aZz   186181144
#
#     from_user_id_str from_user_name from_user_fullname from_user_created_at  \
# 0          250370014    bryanmink15         Bryan Mink  2011-02-10 23:37:39
# 1          498838018          MPD35      Matthew Davis  2012-02-21 13:39:56
# 2          140078549  TravisZimpfer     Travis Zimpfer  2010-05-04 14:16:50
# 3         3359958869  cdavidperry47        Caleb Perry  2015-07-05 05:09:10
# 4         1698103249  justinmayhugh     Justin Mayhugh  2013-08-25 03:50:41
# ..               ...            ...                ...                  ...
# 195       1921298382    reardonevan    evans not funny  2013-09-30 21:17:26
# 196        111336633     mimimugrad  Michelle Chirpich  2010-02-04 15:30:40
# 197         37007656      kehbaybay             kayla.  2009-05-01 18:33:31
# 198        205060572        JenKorf           Jen Korf  2010-10-20 02:12:41
# 199        186181144       CFrost36  Clark Frost , III  2010-09-02 19:46:45
#
#      from_user_followers  ...          from_user_timezone  to_user  \
# 0                    254  ...  Central Time (US & Canada)     None
# 1                    159  ...  Central Time (US & Canada)     None
# 2                    568  ...  Central Time (US & Canada)     None
# 3                     83  ...                        None     None
# 4                    208  ...  Eastern Time (US & Canada)     None
# ..                   ...  ...                         ...      ...
# 195                  405  ...                        None     None
# 196                  268  ...  Central Time (US & Canada)     None
# 197                  322  ...  Central Time (US & Canada)     None
# 198                 1005  ...                        None     None
# 199                  318  ...  Central Time (US & Canada)     None
#
#      to_user_id_str to_user_name  \
# 0              None         None
# 1              None         None
# 2              None         None
# 3              None         None
# 4              None         None
# ..              ...          ...
# 195            None         None
# 196            None         None
# 197            None         None
# 198            None         None
# 199            None         None
#
#                                                 source location_geo  \
# 0    <a href="http://twitter.com/download/iphone" r...         None
# 1    <a href="http://twitter.com/download/iphone" r...         None
# 2    <a href="http://twitter.com/download/android" ...         None
# 3    <a href="http://twitter.com/download/android" ...         None
# 4    <a href="http://twitter.com/download/android" ...         None
# ..                                                 ...          ...
# 195  <a href="http://twitter.com/download/iphone" r...         None
# 196  <a href="http://twitter.com/download/android" ...         None
# 197  <a href="http://twitter.com/download/iphone" r...         None
# 198  <a href="http://twitter.com/download/iphone" r...         None
# 199  <a href="http://twitter.com" rel="nofollow">Tw...         None
#
#     location_geo_0 location_geo_1 iso_language  analysis_state
# 0              NaN            NaN           en               0
# 1              NaN            NaN           en               0
# 2              NaN            NaN           en               0
# 3              NaN            NaN          und               0
# 4              NaN            NaN          und               0
# ..             ...            ...          ...             ...
# 195            NaN            NaN           en               0
# 196            NaN            NaN           en               0
# 197            NaN            NaN          und               0
# 198            NaN            NaN           en               0
# 199            NaN            NaN          und               0
#
# [200 rows x 23 columns]

# %% [markdown]
# The database also collects the language that the tweet was written in as long as it is identifiable. This is stored in the `iso_language` column as an attribute of the `tweet`.
#
# **Exercise 3**: Write and execute a query that returns the distinct languages and the count of each language for 2000 rows in Columbia, MO. Keep in mind this will be a nested query and that at the lowest level you have a limit of 2000.

# %%
# Code for Exercise 3 goes here
# ------------

statement = """
SELECT DISTINCT iso_language, COUNT(*), job_id
FROM(
    SELECT iso_language, job_id
    FROM twitter.tweet
    WHERE job_id = 261
    LIMIT 2000) AS t1
GROUP BY iso_language, job_id
"""

pd.read_sql_query(statement,conn)
# Out:
#    iso_language  count  job_id
# 0            de      1     261
# 1            en   1665     261
# 2            es      3     261
# 3            fr      1     261
# 4            hi      1     261
# 5            ht     13     261
# 6            in      7     261
# 7            it      2     261
# 8            nl      1     261
# 9            tl      1     261
# 10           tr      1     261
# 11          und    304     261

# %% [markdown]
# **Exercise 4**: Now find out who tweets the most in Columbia, MO for 2000 rows of data. Arrange the data in descending order by count. User ids are stored in the `from_user` attribute.

# %%
# Code for Exercise 4 goes here
# ------------

statement = """
SELECT DISTINCT from_user, COUNT(*)
FROM(
    SELECT from_user
    FROM twitter.tweet
    WHERE job_id = 261
    LIMIT 2000) AS t2
GROUP BY from_user
ORDER BY count DESC;
"""

pd.read_sql_query(statement,conn)
# Out:
#        from_user  count
# 0       23220667     32
# 1       48932450     31
# 2      449210670     20
# 3       30032915     18
# 4     1280818093     16
# ...          ...    ...
# 1199    97750419      1
# 1200    98529068      1
# 1201    99323953      1
# 1202   993643334      1
# 1203   995678191      1
#
# [1204 rows x 2 columns]

# %% [markdown]
# the column `from_user_followers` stores the number of followers the user who wrote the tweet had when that tweet was created.
#
# **Challenge Question 1**: Write and execute a query that finds the average number of `from_user_followers` for each distinct `iso_language` from only 2000 rows of Columbia, MO tweets.

# %%
# Code for Challenge Question 1 goes here
# ------------

statement = """
SELECT DISTINCT iso_language, AVG(from_user_followers)
FROM(
    SELECT iso_language, from_user_followers
    FROM twitter.tweet
    WHERE job_id = 261
    LIMIT 2000) AS t3
GROUP BY iso_language
ORDER BY avg
"""

pd.read_sql_query(statement,conn)
# Out:
#    iso_language          avg
# 0            fi    71.000000
# 1            th   142.000000
# 2            lt   209.333333
# 3            et   279.000000
# 4            es   370.000000
# 5            pl   594.500000
# 6            cy   626.000000
# 7            tl   640.500000
# 8            fr   732.000000
# 9           und   857.338129
# 10           in   866.000000
# 11           de  1045.666667
# 12           ht  1884.000000
# 13           en  1916.221133

# %% [markdown]
# # Save your notebook, then `File > Close and Halt`
