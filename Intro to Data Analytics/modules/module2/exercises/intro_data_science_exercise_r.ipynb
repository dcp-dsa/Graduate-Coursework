# %% [markdown]
# # Manipulating Data with `R` Exercises
#
# In this Exercise notebook, you will be manipulating the Congress Terms data set with `R`. These data record some general information about every member in Congress dating back to the 1940s. We encourage you play get your hands dirty, and play around with this new data set to familiarize yourself with it. Be sure to follow the directions carefully and write as well as execute code in the designated cells.

# %% [markdown]
# **Question 1**: Read in the file `congress-terms.csv` under the `/dsa/data/all_datasets/` directory. Name this data frame "`df`".

# %%
# Execute your code for question 1 here
# -------------------------------------

df <- read.csv('/dsa/data/all_datasets/congress-terms.csv')
# Out:
#       congress chamber bioguide firstname   middlename lastname   suffix
# 1     80       house   M000112  Joseph      Jefferson  Mansfield
# 2     80       house   D000448  Robert      Lee        Doughton
# 3     80       house   S000001  Adolph      Joachim    Sabath
# 4     80       house   E000023  Charles     Aubrey     Eaton
# 5     80       house   L000296  William                Lewis
# 6     80       house   G000017  James       A.         Gallagher
# 7     80       house   W000265  Richard     Joseph     Welch
# 8     80       house   B000565  Sol                    Bloom
# 9     80       house   H000943  Merlin                 Hull
# 10    80       house   G000169  Charles     Laceille   Gifford
# 11    80       house   B000545  Schuyler    Otis       Bland
# 12    80       house   R000358  John        Marshall   Robsion
# 13    80       house   L000501  Louis       Leon       Ludlow
# 14    80       house   K000138  John        Hosea      Kerr
# 15    80       house   C000932  Robert                 Crosser
# 16    80       house   L000163  Clarence    Frederick  Lea
# 17    80       house   K000039  John                   Kee
# 18    80       house   S000717  Brent                  Spence
# 19    80       house   A000257  Homer       Daniel     Angell
# 20    80       house   N000153  Mary        Teresa     Norton
# 21    80       house   P000395  Charles     Albert     Plumley
# 22    80       house   D000496  Patrick     Henry      Drewry
# 23    80       house   H000683  Clare       Eugene     Hoffman
# 24    80       house   R000113  Daniel      Alden      Reed
# 25    80       house   B001214  William     Thomas     Byrne
# 26    80       house   W000718  Roy         Orchard    Woodruff
# 27    80       house   B000515  William     Wallace    Blackney
# 28    80       house   M000693  Earl        Cory       Michener
# 29    80       house   C000590  Howard      Aldridge   Coffin
# 30    80       house   M000374  Edward      Oscar      McCowen
# ⋮     ⋮        ⋮       ⋮        ⋮           ⋮          ⋮          ⋮
# 18606 113      senate  K000360  Mark        Steven     Kirk
# 18607 113      senate  C001070  Robert      P.         Casey      Jr.
# 18608 113      senate  H001041  Dean                   Heller
# 18609 113      senate  K000367  Amy         Jean       Klobuchar
# 18610 113      senate  W000818  John        E.         Walsh
# 18611 113      senate  T000250  John                   Thune
# 18612 113      senate  V000127  David                  Vitter
# 18613 113      senate  T000461  Patrick     J.         Toomey
# 18614 113      senate  B001230  Tammy                  Baldwin
# 18615 113      senate  B001265  Mark                   Begich
# 18616 113      senate  F000444  Jeff                   Flake
# 18617 113      senate  P000603  Rand                   Paul
# 18618 113      senate  P000590  Mark                   Pryor
# 18619 113      senate  C001088  Chris       Andrew     Coons
# 18620 113      senate  B001267  Michael     F.         Bennet
# 18621 113      senate  S001184  Tim                    Scott
# 18622 113      senate  G000555  Kirsten     E.         Gillibrand
# 18623 113      senate  A000368  Kelly                  Ayotte
# 18624 113      senate  B001288  Cory        Anthony    Booker
# 18625 113      senate  C001098  Ted                    Cruz
# 18626 113      senate  R000595  Marco                  Rubio
# 18627 113      senate  L000577  Mike                   Lee
# 18628 113      senate  H001046  Martin                 Heinrich
# 18629 113      senate  S001194  Brian       Emanuel    Schatz
# 18630 113      senate  M001169  Christopher S.         Murphy
# 18631 113      senate  B000243  Max         S.         Baucus
# 18632 113      senate  C001099  William                Cowan
# 18633 113      senate  C001100  Jeffrey     Scott      Chiesa
# 18634 113      senate  K000148  John        Forbes     Kerry
# 18635 113      senate  L000123  Frank       R.         Lautenberg
#       birthday   state party incumbent termstart age
# 1     1861-02-09 TX    D     Yes       1/3/47    85.9
# 2     1863-11-07 NC    D     Yes       1/3/47    83.2
# 3     1866-04-04 IL    D     Yes       1/3/47    80.7
# 4     1868-03-29 NJ    R     Yes       1/3/47    78.8
# 5     1868-09-22 KY    R     No        1/3/47    78.3
# 6     1869-01-16 PA    R     No        1/3/47    78.0
# 7     1869-02-13 CA    R     Yes       1/3/47    77.9
# 8     1870-03-09 NY    D     Yes       1/3/47    76.8
# 9     1870-12-18 WI    R     Yes       1/3/47    76.0
# 10    1871-03-15 MA    R     Yes       1/3/47    75.8
# 11    1872-05-04 VA    D     Yes       1/3/47    74.7
# 12    1873-01-02 KY    R     Yes       1/3/47    74.0
# 13    1873-06-24 IN    D     Yes       1/3/47    73.5
# 14    1873-12-31 NC    D     Yes       1/3/47    73.0
# 15    1874-06-07 OH    D     Yes       1/3/47    72.6
# 16    1874-07-11 CA    D     Yes       1/3/47    72.5
# 17    1874-08-22 WV    D     Yes       1/3/47    72.4
# 18    1874-12-24 KY    D     Yes       1/3/47    72.0
# 19    1875-01-12 OR    R     Yes       1/3/47    72.0
# 20    1875-03-07 NJ    D     Yes       1/3/47    71.8
# 21    1875-04-14 VT    R     Yes       1/3/47    71.7
# 22    1875-05-24 VA    D     Yes       1/3/47    71.6
# 23    1875-09-10 MI    R     Yes       1/3/47    71.3
# 24    1875-09-15 NY    R     Yes       1/3/47    71.3
# 25    1876-03-06 NY    D     Yes       1/3/47    70.8
# 26    1876-03-14 MI    R     Yes       1/3/47    70.8
# 27    1876-08-28 MI    R     Yes       1/3/47    70.3
# 28    1876-11-30 MI    R     Yes       1/3/47    70.1
# 29    1877-06-11 MI    R     No        1/3/47    69.6
# 30    1877-06-29 OH    R     Yes       1/3/47    69.5
# ⋮     ⋮          ⋮     ⋮     ⋮         ⋮         ⋮
# 18606 9/15/59    IL    R     Yes       1/3/13    53.3
# 18607 4/13/60    PA    D     Yes       1/3/13    52.7
# 18608 5/10/60    NV    R     Yes       1/3/13    52.7
# 18609 5/25/60    MN    D     Yes       1/3/13    52.6
# 18610 11/3/60    MT    D     No        1/3/13    52.2
# 18611 1/7/61     SD    R     Yes       1/3/13    52.0
# 18612 5/3/61     LA    R     Yes       1/3/13    51.7
# 18613 11/17/61   PA    R     Yes       1/3/13    51.1
# 18614 2/11/62    WI    D     Yes       1/3/13    50.9
# 18615 3/30/62    AK    D     Yes       1/3/13    50.8
# 18616 12/31/62   AZ    R     Yes       1/3/13    50.0
# 18617 1/7/63     KY    R     Yes       1/3/13    50.0
# 18618 1/10/63    AR    D     Yes       1/3/13    50.0
# 18619 9/9/63     DE    D     Yes       1/3/13    49.3
# 18620 11/28/64   CO    D     Yes       1/3/13    48.1
# 18621 9/19/65    SC    R     Yes       1/3/13    47.3
# 18622 12/9/66    NY    D     Yes       1/3/13    46.1
# 18623 6/27/68    NH    R     Yes       1/3/13    44.5
# 18624 4/27/69    NJ    D     No        1/3/13    43.7
# 18625 12/22/70   TX    R     No        1/3/13    42.0
# 18626 5/28/71    FL    R     Yes       1/3/13    41.6
# 18627 6/4/71     UT    R     Yes       1/3/13    41.6
# 18628 10/17/71   NM    D     Yes       1/3/13    41.2
# 18629 10/20/72   HI    D     Yes       1/3/13    40.2
# 18630 8/3/73     CT    D     Yes       1/3/13    39.4
# 18631 12/10/37   MT    D     Yes       1/3/13    75.1
# 18632 4/3/65     MA    D     No        1/3/13    47.8
# 18633 6/21/61    NJ    R     No        1/3/13    51.5
# 18634 12/10/39   MA    D     Yes       1/3/13    73.1
# 18635 1/22/20    NJ    D     Yes       1/3/13    93.0

# %% [markdown]
# **Question 2**: Now split the data frame, `df`, into 2 data frames based on the Republican and Democratic party. Save them in a variables named "`republican`" and "`democrat`" respectively. Which data set has more rows?

# %%
# Execute your code for question 2 here
# -------------------------------------

df1 <- split(df, df$party)

republican <- df1$R
republican

democrat <- df1$D
democrat

nrow(republican)
nrow(democrat) # democrat has more rows
# Out:
#       congress chamber bioguide firstname middlename lastname  suffix
# 4     80       house   E000023  Charles   Aubrey     Eaton
# 5     80       house   L000296  William              Lewis
# 6     80       house   G000017  James     A.         Gallagher
# 7     80       house   W000265  Richard   Joseph     Welch
# 9     80       house   H000943  Merlin               Hull
# 10    80       house   G000169  Charles   Laceille   Gifford
# 12    80       house   R000358  John      Marshall   Robsion
# 19    80       house   A000257  Homer     Daniel     Angell
# 21    80       house   P000395  Charles   Albert     Plumley
# 23    80       house   H000683  Clare     Eugene     Hoffman
# 24    80       house   R000113  Daniel    Alden      Reed
# 26    80       house   W000718  Roy       Orchard    Woodruff
# 27    80       house   B000515  William   Wallace    Blackney
# 28    80       house   M000693  Earl      Cory       Michener
# 29    80       house   C000590  Howard    Aldridge   Coffin
# 30    80       house   M000374  Edward    Oscar      McCowen
# 31    80       house   W000012  James     Wolcott    Wadsworth Jr.
# 34    80       house   L000238  William              Lemke
# 36    80       house   J000117  Anton     Joseph     Johnson
# 39    80       house   A000296  Samuel    Washington Arnold
# 42    80       house   T000001  John                 Taber
# 43    80       house   J000096  John                 Jennings  Jr.
# 44    80       house   G000206  Wilson    Darwin     Gillette
# 45    80       house   G000360  Louis     Edward     Graham
# 46    80       house   G000207  George    W.         Gillie
# 47    80       house   M000574  Rolla     Coral      McMillen
# 48    80       house   K000301  Harold               Knutson
# 49    80       house   W000683  Charles   Anderson   Wolverton
# 50    80       house   J000088  Thomas    Albert     Jenkins
# 53    80       house   G000297  Angier    Louis      Goodwin
# ⋮     ⋮        ⋮       ⋮        ⋮         ⋮          ⋮         ⋮
# 18571 113      senate  B000575  Roy                  Blunt
# 18573 113      senate  J000291  Mike                 Johanns
# 18577 113      senate  B001236  John                 Boozman
# 18578 113      senate  F000463  Deb                  Fischer
# 18579 113      senate  C000880  Michael   D.         Crapo
# 18581 113      senate  W000437  Roger     F.         Wicker
# 18582 113      senate  C001056  John                 Cornyn
# 18583 113      senate  B001261  John      A.         Barrasso
# 18584 113      senate  C001071  Bob                  Corker
# 18586 113      senate  C001035  Susan     M.         Collins
# 18590 113      senate  M000934  Jerry                Moran
# 18592 113      senate  J000293  Ron                  Johnson
# 18593 113      senate  G000359  Lindsey   O.         Graham
# 18598 113      senate  B001135  Richard   M.         Burr
# 18599 113      senate  P000449  Robert    J.         Portman
# 18602 113      senate  H001061  John                 Hoeven
# 18603 113      senate  M001153  Lisa      A.         Murkowski
# 18606 113      senate  K000360  Mark      Steven     Kirk
# 18608 113      senate  H001041  Dean                 Heller
# 18611 113      senate  T000250  John                 Thune
# 18612 113      senate  V000127  David                Vitter
# 18613 113      senate  T000461  Patrick   J.         Toomey
# 18616 113      senate  F000444  Jeff                 Flake
# 18617 113      senate  P000603  Rand                 Paul
# 18621 113      senate  S001184  Tim                  Scott
# 18623 113      senate  A000368  Kelly                Ayotte
# 18625 113      senate  C001098  Ted                  Cruz
# 18626 113      senate  R000595  Marco                Rubio
# 18627 113      senate  L000577  Mike                 Lee
# 18633 113      senate  C001100  Jeffrey   Scott      Chiesa
#       birthday   state party incumbent termstart age
# 4     1868-03-29 NJ    R     Yes       1/3/47    78.8
# 5     1868-09-22 KY    R     No        1/3/47    78.3
# 6     1869-01-16 PA    R     No        1/3/47    78.0
# 7     1869-02-13 CA    R     Yes       1/3/47    77.9
# 9     1870-12-18 WI    R     Yes       1/3/47    76.0
# 10    1871-03-15 MA    R     Yes       1/3/47    75.8
# 12    1873-01-02 KY    R     Yes       1/3/47    74.0
# 19    1875-01-12 OR    R     Yes       1/3/47    72.0
# 21    1875-04-14 VT    R     Yes       1/3/47    71.7
# 23    1875-09-10 MI    R     Yes       1/3/47    71.3
# 24    1875-09-15 NY    R     Yes       1/3/47    71.3
# 26    1876-03-14 MI    R     Yes       1/3/47    70.8
# 27    1876-08-28 MI    R     Yes       1/3/47    70.3
# 28    1876-11-30 MI    R     Yes       1/3/47    70.1
# 29    1877-06-11 MI    R     No        1/3/47    69.6
# 30    1877-06-29 OH    R     Yes       1/3/47    69.5
# 31    1877-08-12 NY    R     Yes       1/3/47    69.4
# 34    1878-08-13 ND    R     Yes       1/3/47    68.4
# 36    1878-10-20 IL    R     Yes       1/3/47    68.2
# 39    1879-09-21 MO    R     Yes       1/3/47    67.3
# 42    1880-05-05 NY    R     Yes       1/3/47    66.7
# 43    1880-06-06 TN    R     Yes       1/3/47    66.6
# 44    1880-07-01 PA    R     Yes       1/3/47    66.5
# 45    1880-08-04 PA    R     Yes       1/3/47    66.4
# 46    1880-08-15 IN    R     Yes       1/3/47    66.4
# 47    1880-10-05 IL    R     Yes       1/3/47    66.2
# 48    1880-10-20 MN    R     Yes       1/3/47    66.2
# 49    1880-10-24 NJ    R     Yes       1/3/47    66.2
# 50    1880-10-28 OH    R     Yes       1/3/47    66.2
# 53    1881-01-30 MA    R     Yes       1/3/47    65.9
# ⋮     ⋮          ⋮     ⋮     ⋮         ⋮         ⋮
# 18571 1/10/50    MO    R     Yes       1/3/13    63.0
# 18573 6/18/50    NE    R     Yes       1/3/13    62.5
# 18577 12/10/50   AR    R     Yes       1/3/13    62.1
# 18578 3/1/51     NE    R     No        1/3/13    61.8
# 18579 5/20/51    ID    R     Yes       1/3/13    61.6
# 18581 7/5/51     MS    R     Yes       1/3/13    61.5
# 18582 2/2/52     TX    R     Yes       1/3/13    60.9
# 18583 7/21/52    WY    R     Yes       1/3/13    60.5
# 18584 8/24/52    TN    R     Yes       1/3/13    60.4
# 18586 12/7/52    ME    R     Yes       1/3/13    60.1
# 18590 5/29/54    KS    R     Yes       1/3/13    58.6
# 18592 4/8/55     WI    R     Yes       1/3/13    57.7
# 18593 7/9/55     SC    R     Yes       1/3/13    57.5
# 18598 11/30/55   NC    R     Yes       1/3/13    57.1
# 18599 12/19/55   OH    R     Yes       1/3/13    57.0
# 18602 3/13/57    ND    R     Yes       1/3/13    55.8
# 18603 5/22/57    AK    R     Yes       1/3/13    55.6
# 18606 9/15/59    IL    R     Yes       1/3/13    53.3
# 18608 5/10/60    NV    R     Yes       1/3/13    52.7
# 18611 1/7/61     SD    R     Yes       1/3/13    52.0
# 18612 5/3/61     LA    R     Yes       1/3/13    51.7
# 18613 11/17/61   PA    R     Yes       1/3/13    51.1
# 18616 12/31/62   AZ    R     Yes       1/3/13    50.0
# 18617 1/7/63     KY    R     Yes       1/3/13    50.0
# 18621 9/19/65    SC    R     Yes       1/3/13    47.3
# 18623 6/27/68    NH    R     Yes       1/3/13    44.5
# 18625 12/22/70   TX    R     No        1/3/13    42.0
# 18626 5/28/71    FL    R     Yes       1/3/13    41.6
# 18627 6/4/71     UT    R     Yes       1/3/13    41.6
# 18633 6/21/61    NJ    R     No        1/3/13    51.5
#       congress chamber bioguide firstname   middlename lastname    suffix
# 1     80       house   M000112  Joseph      Jefferson  Mansfield
# 2     80       house   D000448  Robert      Lee        Doughton
# 3     80       house   S000001  Adolph      Joachim    Sabath
# 8     80       house   B000565  Sol                    Bloom
# 11    80       house   B000545  Schuyler    Otis       Bland
# 13    80       house   L000501  Louis       Leon       Ludlow
# 14    80       house   K000138  John        Hosea      Kerr
# 15    80       house   C000932  Robert                 Crosser
# 16    80       house   L000163  Clarence    Frederick  Lea
# 17    80       house   K000039  John                   Kee
# 18    80       house   S000717  Brent                  Spence
# 20    80       house   N000153  Mary        Teresa     Norton
# 22    80       house   D000496  Patrick     Henry      Drewry
# 25    80       house   B001214  William     Thomas     Byrne
# 32    80       house   O000016  Thomas      Joseph     O'Brien
# 33    80       house   W000430  William     Madison    Whittington
# 35    80       house   D000212  John        Joseph     Delaney
# 37    80       house   C000117  Clarence    Andrew     Cannon
# 38    80       house   T000189  Robert      Ewing      Thomason
# 40    80       house   B000940  Paul                   Brown
# 41    80       house   C000831  Edward      Eugene     Cox
# 51    80       house   F000241  John        Hamlin     Folger
# 52    80       house   Z000009  Orville                Zimmerman
# 57    80       house   R000082  Samuel      Taliaferro Rayburn
# 59    80       house   R000056  John        Elliott    Rankin
# 60    80       house   C000439  Jerome      Bayard     Clark
# 63    80       house   H000356  Franck      Roberts    Havenner
# 64    80       house   S000554  Howard      Worth      Smith
# 65    80       house   B001056  Alfred      Lee        Bulwinkle
# 68    80       house   K000058  Augustine   Bernard    Kelley
# ⋮     ⋮        ⋮       ⋮        ⋮           ⋮          ⋮           ⋮
# 18585 113      senate  B000944  Sherrod                Brown
# 18587 113      senate  H001049  Kay                    Hagan
# 18588 113      senate  M001170  Claire                 McCaskill
# 18589 113      senate  M000639  Robert                 Men̩ndez
# 18591 113      senate  W000805  Mark                   Warner
# 18594 113      senate  D000607  Joe                    Donnelly
# 18595 113      senate  W000802  Sheldon                Whitehouse
# 18596 113      senate  H001069  Heidi                  Heitkamp
# 18597 113      senate  L000550  Mary        L.         Landrieu
# 18600 113      senate  T000464  Jon                    Tester
# 18601 113      senate  M001176  Jeff                   Merkley
# 18604 113      senate  K000384  Timothy                Kaine
# 18605 113      senate  C000127  Maria                  Cantwell
# 18607 113      senate  C001070  Robert      P.         Casey       Jr.
# 18609 113      senate  K000367  Amy         Jean       Klobuchar
# 18610 113      senate  W000818  John        E.         Walsh
# 18614 113      senate  B001230  Tammy                  Baldwin
# 18615 113      senate  B001265  Mark                   Begich
# 18618 113      senate  P000590  Mark                   Pryor
# 18619 113      senate  C001088  Chris       Andrew     Coons
# 18620 113      senate  B001267  Michael     F.         Bennet
# 18622 113      senate  G000555  Kirsten     E.         Gillibrand
# 18624 113      senate  B001288  Cory        Anthony    Booker
# 18628 113      senate  H001046  Martin                 Heinrich
# 18629 113      senate  S001194  Brian       Emanuel    Schatz
# 18630 113      senate  M001169  Christopher S.         Murphy
# 18631 113      senate  B000243  Max         S.         Baucus
# 18632 113      senate  C001099  William                Cowan
# 18634 113      senate  K000148  John        Forbes     Kerry
# 18635 113      senate  L000123  Frank       R.         Lautenberg
#       birthday   state party incumbent termstart age
# 1     1861-02-09 TX    D     Yes       1/3/47    85.9
# 2     1863-11-07 NC    D     Yes       1/3/47    83.2
# 3     1866-04-04 IL    D     Yes       1/3/47    80.7
# 8     1870-03-09 NY    D     Yes       1/3/47    76.8
# 11    1872-05-04 VA    D     Yes       1/3/47    74.7
# 13    1873-06-24 IN    D     Yes       1/3/47    73.5
# 14    1873-12-31 NC    D     Yes       1/3/47    73.0
# 15    1874-06-07 OH    D     Yes       1/3/47    72.6
# 16    1874-07-11 CA    D     Yes       1/3/47    72.5
# 17    1874-08-22 WV    D     Yes       1/3/47    72.4
# 18    1874-12-24 KY    D     Yes       1/3/47    72.0
# 20    1875-03-07 NJ    D     Yes       1/3/47    71.8
# 22    1875-05-24 VA    D     Yes       1/3/47    71.6
# 25    1876-03-06 NY    D     Yes       1/3/47    70.8
# 32    1878-04-30 IL    D     Yes       1/3/47    68.7
# 33    1878-05-04 MS    D     Yes       1/3/47    68.7
# 35    1878-08-21 NY    D     Yes       1/3/47    68.4
# 37    1879-04-11 MO    D     Yes       1/3/47    67.7
# 38    1879-05-30 TX    D     Yes       1/3/47    67.6
# 40    1880-03-31 GA    D     Yes       1/3/47    66.8
# 41    1880-04-03 GA    D     Yes       1/3/47    66.7
# 51    1880-12-18 NC    D     Yes       1/3/47    66.0
# 52    1880-12-31 MO    D     Yes       1/3/47    66.0
# 57    1882-01-06 TX    D     Yes       1/3/47    65.0
# 59    1882-03-29 MS    D     Yes       1/3/47    64.8
# 60    1882-04-05 NC    D     Yes       1/3/47    64.7
# 63    1882-09-20 CA    D     Yes       1/3/47    64.3
# 64    1883-02-02 VA    D     Yes       1/3/47    63.9
# 65    1883-04-21 NC    D     Yes       1/3/47    63.7
# 68    1883-07-09 PA    D     Yes       1/3/47    63.5
# ⋮     ⋮          ⋮     ⋮     ⋮         ⋮         ⋮
# 18585 11/9/52    OH    D     Yes       1/3/13    60.2
# 18587 5/26/53    NC    D     Yes       1/3/13    59.6
# 18588 7/24/53    MO    D     Yes       1/3/13    59.4
# 18589 1/1/54     NJ    D     Yes       1/3/13    59.0
# 18591 12/15/54   VA    D     Yes       1/3/13    58.1
# 18594 9/28/55    IN    D     Yes       1/3/13    57.3
# 18595 10/20/55   RI    D     Yes       1/3/13    57.2
# 18596 10/30/55   ND    D     No        1/3/13    57.2
# 18597 11/23/55   LA    D     Yes       1/3/13    57.1
# 18600 8/21/56    MT    D     Yes       1/3/13    56.4
# 18601 10/24/56   OR    D     Yes       1/3/13    56.2
# 18604 2/26/58    VA    D     No        1/3/13    54.9
# 18605 10/13/58   WA    D     Yes       1/3/13    54.2
# 18607 4/13/60    PA    D     Yes       1/3/13    52.7
# 18609 5/25/60    MN    D     Yes       1/3/13    52.6
# 18610 11/3/60    MT    D     No        1/3/13    52.2
# 18614 2/11/62    WI    D     Yes       1/3/13    50.9
# 18615 3/30/62    AK    D     Yes       1/3/13    50.8
# 18618 1/10/63    AR    D     Yes       1/3/13    50.0
# 18619 9/9/63     DE    D     Yes       1/3/13    49.3
# 18620 11/28/64   CO    D     Yes       1/3/13    48.1
# 18622 12/9/66    NY    D     Yes       1/3/13    46.1
# 18624 4/27/69    NJ    D     No        1/3/13    43.7
# 18628 10/17/71   NM    D     Yes       1/3/13    41.2
# 18629 10/20/72   HI    D     Yes       1/3/13    40.2
# 18630 8/3/73     CT    D     Yes       1/3/13    39.4
# 18631 12/10/37   MT    D     Yes       1/3/13    75.1
# 18632 4/3/65     MA    D     No        1/3/13    47.8
# 18634 12/10/39   MA    D     Yes       1/3/13    73.1
# 18635 1/22/20    NJ    D     Yes       1/3/13    93.0
# [1] 8274
# [1] 10290

# %% [markdown]
# **Question 3**:  Are there any other codes for political parties other than Democrat and Republican? If so, what are these other codes? What function did you use to find this?

# %%
# Write your code for question 3 here
# -------------------------------------

unique(df['party'])
# Out:
#      party
# 1    D
# 4    R
# 335  AL
# 985  L
# 1110 I
# 3664 ID

# %% [raw]
# Answer the question above here.
# 3. Using the "unique" function, I found that the additional codes are 'AL', 'L', 'I', and 'ID'

# %% [markdown]
# **Question 4**: Sort the `republicans` and `democrats` data frames by age and return the 5 oldest and youngest from each party.

# %%
# Execute your code for question 4 here
# -------------------------------------

r_age <- republican[order(republican$age),]
head(r_age, n = 5)
tail(r_age, n = 5)

d_age <- democrat[order(democrat$age),]
head(d_age, n = 5)
tail(d_age, n = 5)
# Out:
#       congress chamber bioguide firstname middlename lastname     suffix
# 8166   94      house   E000175  David     Farnham    Emery
# 15255 107      house   P000586  Adam      H.         Putnam
# 2110   83      house   W000121  William   Creed      Wampler
# 452    80      house   S000063  George    William    Sarbacher    Jr.
# 9814   97      house   L000547  John                 LeBoutillier
#       birthday state party incumbent termstart age
# 8166  9/1/48   ME    R     No        1/14/75   26.4
# 15255 7/31/74  FL    R     No        1/3/01    26.4
# 2110  4/21/26  VA    R     No        1/3/53    26.7
# 452   9/30/19  PA    R     No        1/3/47    27.3
# 9814  5/26/53  NY    R     No        1/5/81    27.6
#       congress chamber bioguide firstname middlename lastname suffix birthday
# 13082 103      senate  T000254  J.        Strom      Thurmond        1902-12-05
# 13628 104      senate  T000254  J.        Strom      Thurmond        1902-12-05
# 14175 105      senate  T000254  J.        Strom      Thurmond        1902-12-05
# 14712 106      senate  T000254  J.        Strom      Thurmond        1902-12-05
# 15256 107      senate  T000254  J.        Strom      Thurmond        1902-12-05
#       state party incumbent termstart age
# 13082 SC    R     Yes       1/5/93    90.1
# 13628 SC    R     Yes       1/4/95    92.1
# 14175 SC    R     Yes       1/7/97    94.1
# 14712 SC    R     Yes       1/6/99    96.1
# 15256 SC    R     Yes       1/3/01    98.1
#       congress chamber bioguide firstname middlename lastname suffix birthday
# 5423   89      house   J000151  Jed       Joseph     Johnson  Jr.    12/27/39
# 453    80      house   B000401  Lloyd     Millard    Bentsen  Jr.    2/11/21
# 8167   94      house   D000471  Thomas    Joseph     Downey          1/28/49
# 5422   89      house   G000420  William   Joseph     Green           6/24/38
# 14174 105      house   F000262  Harold    E.         Ford     Jr.    5/11/70
#       state party incumbent termstart age
# 5423  OK    D     No        1/4/65    25.0
# 453   TX    D     No        1/3/47    25.9
# 8167  NY    D     No        1/14/75   26.0
# 5422  PA    D     No        1/4/65    26.5
# 14174 TN    D     No        1/7/97    26.7
#       congress chamber bioguide firstname middlename lastname   suffix
# 5968   90      senate  H000385  Carl      Trumbull   Hayden
# 18091 112      senate  I000025  Daniel    K.         Inouye
# 3764   86      senate  G000418  Theodore  Francis    Green
# 18635 113      senate  L000123  Frank     R.         Lautenberg
# 17536 111      senate  B001210  Robert    C.         Byrd
#       birthday   state party incumbent termstart age
# 5968  1877-10-02 AZ    D     Yes       1/10/67   89.3
# 18091 9/6/20     HI    D     Yes       1/5/11    90.3
# 3764  1867-10-02 RI    D     Yes       1/7/59    91.3
# 18635 1/22/20    NJ    D     Yes       1/3/13    93.0
# 17536 11/19/13   WV    D     Yes       1/6/09    95.1

# %% [markdown]
# **Question 5**: Now, let's start using the package `dplyr` to perform some basic data manipulations. If you noticed, the `df$chamber` column contains whether or not the individual belonged to the `house` or the `senate`. Using `dplyr` create a frame of data that returns the youngest member from each chamber per party (including those other than Republican or Democrat).

# %%
# Execute your code for question 5 here
# -------------------------------------

library(dplyr)

df2 <- df %>% arrange(chamber) %>% group_by(chamber, party) %>% filter(age == min(age))
df2
# Out:
#    congress chamber bioguide firstname middlename lastname  suffix birthday
# 1   80      house   I000046  Leo                  Isacson          4/20/10
# 2   81      house   R000425  Franklin  Delano     Roosevelt Jr.    8/17/14
# 3   86      house   A000105  Thomas    Dale       Alford           1/28/16
# 4   89      house   J000151  Jed       Joseph     Johnson   Jr.    12/27/39
# 5   94      house   E000175  David     Farnham    Emery            9/1/48
# 6  102      house   S000033  Bernard              Sanders          9/8/41
# 7  107      house   P000586  Adam      H.         Putnam           7/31/74
# 8   80      senate  L000428  Russell   Billiu     Long             11/3/18
# 9   88      senate  M000851  Walter    Frederick  Mondale          1/5/28
# 10  97      senate  N000102  Don                  Nickles          12/6/48
# 11 110      senate  L000304  Joseph    I.         Lieberman        2/24/42
#    state party incumbent termstart age
# 1  NY    AL    No        1/3/47    36.7
# 2  NY    L     No        1/3/49    34.4
# 3  AR    ID    No        1/7/59    42.9
# 4  OK    D     No        1/4/65    25.0
# 5  ME    R     No        1/14/75   26.4
# 6  VT    I     No        1/3/91    49.3
# 7  FL    R     No        1/3/01    26.4
# 8  LA    D     Yes       1/3/47    28.2
# 9  MN    I     No        1/9/63    35.0
# 10 OK    R     No        1/5/81    32.1
# 11 CT    ID    Yes       1/4/07    64.9

# %% [markdown]
# **Question 6**: Now, using `dplyr`, create the same frame as above except for the oldest member per chamber, per party.

# %%
# Execute your code for question 6 here
# -------------------------------------

library(dplyr)

df3 <- df %>% arrange(chamber) %>% group_by(chamber, party) %>% filter(age == max(age))
df3
# Out:
#    congress chamber bioguide firstname middlename lastname    suffix birthday
# 1   81      house   M000122  Vito      Anthony    Marcantonio        1902-12-10
# 2   81      house   R000425  Franklin  Delano     Roosevelt   Jr.    8/17/14
# 3   93      house   M000834  John      Joseph     Moakley            4/27/27
# 4  101      house   P000218  Claude    Denson     Pepper             1900-09-08
# 5  109      house   S000033  Bernard              Sanders            9/8/41
# 6  113      house   H000067  Ralph     M.         Hall               5/3/23
# 7  107      senate  T000254  J.        Strom      Thurmond           1902-12-05
# 8  111      senate  L000304  Joseph    I.         Lieberman          2/24/42
# 9  111      senate  B001210  Robert    C.         Byrd               11/19/13
# 10 113      senate  S000033  Bernard              Sanders            9/8/41
#    state party incumbent termstart age
# 1  NY    AL    Yes       1/3/49    46.1
# 2  NY    L     No        1/3/49    34.4
# 3  MA    ID    No        1/3/73    45.7
# 4  FL    D     Yes       1/3/89    88.3
# 5  VT    I     Yes       1/4/05    63.3
# 6  TX    R     Yes       1/3/13    89.7
# 7  SC    R     Yes       1/3/01    98.1
# 8  CT    ID    Yes       1/6/09    66.9
# 9  WV    D     Yes       1/6/09    95.1
# 10 VT    I     Yes       1/3/13    71.3

# %% [markdown]
# # Save your notebook, then `File > Close and Halt`
